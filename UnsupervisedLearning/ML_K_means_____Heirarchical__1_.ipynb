# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhu-psit/MachineLearning/blob/master/UnsupervisedLearning/ML_K_means_____Heirarchical__1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problems with K-Means

# %% [markdown]
# ### **K-Means Intitialization**
#
# - K-Means is **Initialization dependent**. This is one of the major drawbacks of K-Means.
#
# - This means, that the same data, with different initialization, will get different results (different clusters)
# - The clusters formed in K-Means algorithm depend a lot on the way how initialize the centroids.
#
# <img src='https://drive.google.com/uc?id=1KGZH4R5spf-nbx975TVct8POa7i8m3Wm'>

# %% [markdown]
# > **Instructor Notes:**
#
# Images shown below can be found here: https://cs.wmich.edu/alfuqaha/summer14/cs6530/lectures/ClusteringAnalysis.pdf
#
# Alternative link: https://drive.google.com/file/d/1ok4aGA1AZna3XyodOrLO8DYbZImpI7l9/view?usp=sharing
#
# The docoument belongs to folks at University of Michigan. You can mention this in the lecture.

# %% [markdown]
# #### This is how K-Means would give different results with different initializations
#
# <img src="https://drive.google.com/uc?export=view&id=1_8XrEVwmo47dHUkJfNKXXtF1CQE5eMG2">
#
# * In Optimal Clustering results, results are sensible
# * In Sub-Optimal Clustering, which probably doesn't make sense and won't be an optimal one

# %% [markdown]
# > **Instructor Notes**
#
# Use this <a href ="https://www.naftaliharris.com/blog/visualizing-k-means-clustering/">visualization tool </a> for intuitive explanation of K-Means initialization problem. While choosing. You can play around with different options, and can use whatever suits best

# %% [markdown]
# </br>
#
# <img src='https://drive.google.com/uc?id=1v-wCAVvoNeMjpEnzxas0HNyGBKyeix5C' height='300' width='600'>
#
# </br>
#
# <img src='https://drive.google.com/uc?id=1_t_ZM8CtFhMWbLPAmwKQhip0wQP9YVDV' height='300' width='600'>
#
# </br>
#
# <img src='https://drive.google.com/uc?id=1oNdh2KytzXbH_Av3zgzgSX7BBsUXF6pB' height='300' width='600'>
#
# </br>

# %% [markdown]
# ## K-Means ++ Algorithm

# %% [markdown]
# K-Means ++ gives us a better way to initialize the clusters.
#
# 1. Choose any existing data point as a centroid.
# 2. Then, while selecting the second centroid, choose another existing data point which is at farthest distance from the previous one.
# 3. Now, the third centroid should be at farthest distance from both the previous centroids.
#
# </br>
#
# <img src='https://drive.google.com/uc?id=1GLUR-93dgBACFhUfRYUaQ3wLGtyAuZzU' height='300' width='600'>
#
# </br>
#
# The only drawback is that it gives devastating results when we have an outlier present in the data.
#
#
# **NOTE :**
# The initialization times for K-Means ++ could be slightly higher than the original K-Means algorithm.

# %% [markdown]
# ## Limitations of K-Means / K-Means ++

# %% [markdown]
# > **Instructor Notes:**
#
# Images shown below can be found here: https://cs.wmich.edu/alfuqaha/summer14/cs6530/lectures/ClusteringAnalysis.pdf
#
# Alternative link: https://drive.google.com/file/d/1ok4aGA1AZna3XyodOrLO8DYbZImpI7l9/view?usp=sharing
#
# The docoument belongs to folks at University of Michigan. You can mention this in the lecture.

# %% [markdown]
# ### Problem in indentifying clusters of different **sizes**.
#
# <img src='https://drive.google.com/uc?id=1OPT0ZQQb_08zVLLzNV4coAXCbIB0eoqC' height='300' width='600'>
#
# <img src='https://drive.google.com/uc?id=11MF76x7jHAxkJA38gMlIa-x-k4Wo8xCi' height='300' width='600'>
#
# <img src="https://drive.google.com/uc?export=view&id=1DKEwQtMCsrBcstUzLOlX06wkMBvJjiCO">

# %% [markdown]
# ### Problem in identifying clusters with different **densities**.
#
# <img src='https://drive.google.com/uc?id=1fbdgQX1GFHaGEYaeS5yBS2DwUJ6Q1T-T' height='300' width='600'>
#
# <img src='https://drive.google.com/uc?id=10S8qx-6AHKODf4kVDhCAjI-L_fs9pwQL' height='300' width='600'>
#
# <img src="https://drive.google.com/uc?export=view&id=18s3PCi_JVCaxSqgXSJmewy9wP26GeGM2">

# %% [markdown]
# ### Problem in identifying clusters of non-globular **shapes**.
#
# <img src='https://drive.google.com/uc?id=1_D7-qoXuATqcoPUUTLlGs4phVhllNX61' height='300' width='600'>
#
# <img src="https://drive.google.com/uc?export=view&id=15ELbeS7zULGstT8Zsx3fF-AB1L7eSh_L">

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# Here, choosing the no. of clusters becomes slightly more intuitive as compared to KMeans/ KMeans ++.
#
# There are two ways of performing Hierarchical Clustering
#
#   1. Agglomerative (Popular and Widely used)
#   2. Divisive

# %% [markdown]
# #### What is Agglomerative Clustering?
#
# - The word agglomerative suggests combining things
# - It is a **bottom-up** approach
# - Agglomerative clustering starts with the assumption that every datapoint is a cluster
# - Then, it groups the clusters which are closed to each other until there is only a single cluster left
#
# <img src="https://drive.google.com/uc?export=view&id=1QFeq1V0dwWXwwM8WvCUbN3Z8Wrw14y3a">

# %% [markdown]
# #### What is Divisive Clustering?
#
# - It is an complete opposite of agglomerative approach
# - It is a **top-down** approach
# - It starts with one big clusters that conatins all the datapoints.
# - It then divides the points into different clusters till each data point is a cluster itself

# %% [markdown]
# #### Agglomerative clustering Case study
# - This dataset contains customer's spending data. The task is to analyze the customer's spending we are going to use the Hierarchical Clustering algorithm to cluster the customers based on their spending patterns. Given dataset contains following columns:
#
#   - Cust_ID : Shows the customerID assigned by the system
#   - Name : Name of the customer
#   - Avg_Mthly_Spend : Customer's Average monthly spending
#   - No_Of_Visits : Count of the customer's visit to store
#   - Apparel_Items : Count of Apparel item
#   - FnV_Items : Count of Food and Vegetables items
#   - Staples_Items : Count of Staples items

# %% [markdown]
# ### What does the Agglomerative Algorithm look like?
# Now, let's dive a little deep into Agglomerative approach
#
#
# 1. Assume each point is a cluster (n datapoints -> n clusters)
# 2. Compute Proximity Matrix  ($P_{n*n})$
# 3. Repeat until a single cluster is left:
#   - Merge the closest clusters
#   - Update the proximity matrix
#
# - If we visualize this, this looks like a Tree, but there is other name which is often used in Data Mining terminology which is called **Dendogram**
#
# <img src="https://drive.google.com/uc?export=view&id=1neRTN8VRhRVcfyWMFv9ptYysH50wJAOF">
#
# Given below is a very nice animation which depicts the same process.

# %%
from IPython.display import Image
Image(url='https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/015/038/original/hierarch.gif?1663699414')
# Out:
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/015/038/original/hierarch.gif?1663699414"/>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1vCOmzTLsxtWH6758tklJ26sxwJpDjiwh' height='300' width='600'>
#
# </br>
#
# NOTE : </br>
# Don't forget to **standardize** the data before you start calculating the distances between 2 customers.

# %% [markdown]
# For customers 'A' to 'J'. </br>
# We will calculate the distance between each pair of customers in form of a matrix.
#
# </br>
#
# <img src='https://drive.google.com/uc?id=1_R3OEkGznqru1GDt9SZxxLMsB6WoCOGN' height='300' width='600'>
#
# </br>
#
# After that, we will create a graph.
#
# </br>
# Let's say the two points H and I are closest to each other. It means that customer H and customer I have very similar properties. So if H spends certain amount then I is also likely to spend almost the same amount.
#
# <img src='https://drive.google.com/uc?id=1gnOeqzjBhGNw-oNeOQe8WuRzexs8hOGP' height='300' width='600'>

# %% [markdown]
# - Now you might think that after grouping A and B togther we might find that F and G are closest and can be grouped together but there might also be the case that group AB is more closest to group C ad E compared to points F and G
# - but we might not be able to get this infomration using the matrix that we have computed above to do that we have different methods that we'll see next.

# %% [markdown]
# ###Quiz:
# ```
# Do Agglomerative and Divisive approaches give identical results, where the number of clusters and the datapoints in each clusters will be same?
#
# a. Yes
# b. No
# c. Maybe / Maybe not
# ```
# Answer: c

# %% [markdown]
# ### Q. How are we going to compute the similarity between groups of customers?
#
# Let's say if we have two clusters then we can use - </br>
#
# - **Single linkage** :
# We take the minimum possible distance between any two points of the clusters.
#
# - **Complete linkage**:
# We take the farthest possible distance between any two points of the clusters.
#
# <img src='https://drive.google.com/uc?id=1k4lvnmAZ3F8LkCrpa2bp8CU1r2HeNxPO' height='300' width='600'>
#
# - **Average linkage:**
# We take the average distance between all the points of one cluster to the other cluster.
#
# - **Centroid linkage:**
# We find out the centroid points of the two clusters and then calculate the distance between them.
#
# <img src='https://drive.google.com/uc?id=1z9HwxACwQ0tBXqnQGVwJftZ9vm6NL5js' height='300' width='600'>

# %% [markdown]
# ### **Ward method**

# %% [markdown]
# It sees that combining which two clusters is going to create minimum variance.
#
# </br>
#
# <img src='https://drive.google.com/uc?id=17S90_Z75dmj587c_MXpnwNJ-xrPVMs7l' height='300' width='600'>
#
# </br>
#
#   - First figure out the centroid of the two clusters.
#   - Then calculate the variance of the data points in the cluster. </br> $var = \sum{d_i^2}$ </br>
#     Where $d_i$ is the distance of each point with the centroid.
#   - When we combine these two clusters, we again find a centroid and calculate the variance.
#   - Now, the variance will definitely increase. </br> So we choose the two clusters to be merged in such a way that the increase in variance is minimal.

# %% [markdown]
# ### Dendogram

# %% [markdown]
# This graph that we've created is known as **Dendogram**.
#
# </br>
#
# <img src='https://drive.google.com/uc?id=1J22KzVBQaZ1k1rSUiXOMb21mH8zL42ey' height='300' width='600'>
#
# </br>
#
# - Based on the no. of clusters you want, you can cut the Dendogram as shown in the picture above.
# - It depends a lot on your business uinderstanding where you wanna cut since there's a tradeoff.
# - The lower the distance of cut, the closer the clusters are.

# %% [markdown]
# > **Instructor Notes**
# - Make them familiar with hyperparameters of sklearn from <a href = "https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html"> this link </a>

# %%
# !gdown 1XNQvD8RtK49KNIR7VK9nkmb6tTPNXwVu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XNQvD8RtK49KNIR7VK9nkmb6tTPNXwVu
# To: /content/Cust_Spend_Data.csv
# 100% 266/266 [00:00<00:00, 681kB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
import seaborn as sns

# %matplotlib inline

# %%
# reading the CSV file into pandas dataframe
custData = pd.read_csv("Cust_Spend_Data.csv")
custData.head(10)
# Out:
#    Cust_ID Name  Avg_Mthly_Spend  No_Of_Visits  Apparel_Items  FnV_Items  \
# 0        1    A            10000             2              1          1
# 1        2    B             7000             3              0         10
# 2        3    C             7000             7              1          3
# 3        4    D             6500             5              1          1
# 4        5    E             6000             6              0         12
# 5        6    F             4000             3              0          1
# 6        7    G             2500             5              0         11
# 7        8    H             2500             3              0          1
# 8        9    I             2000             2              0          2
# 9       10    J             1000             4              0          1
#
#    Staples_Items
# 0              0
# 1              9
# 2              4
# 3              4
# 4              3
# 5              8
# 6              2
# ...

# %%
custDataAttr=custData.iloc[:,2:]
custDataAttr.head()
# Out:
#    Avg_Mthly_Spend  No_Of_Visits  Apparel_Items  FnV_Items  Staples_Items
# 0            10000             2              1          1              0
# 1             7000             3              0         10              9
# 2             7000             7              1          3              4
# 3             6500             5              1          1              4
# 4             6000             6              0         12              3

# %%
custDataScaled=custDataAttr.apply(zscore)
custDataScaled.head(10)
# Out:
#    Avg_Mthly_Spend  No_Of_Visits  Apparel_Items  FnV_Items  Staples_Items
# 0         1.886498     -1.240347       1.527525  -0.741433      -1.380131
# 1         0.787567     -0.620174      -0.654654   1.280656       1.725164
# 2         0.787567      1.860521       1.527525  -0.292080       0.000000
# 3         0.604412      0.620174       1.527525  -0.741433       0.000000
# 4         0.421257      1.240347      -0.654654   1.730009      -0.345033
# 5        -0.311364     -0.620174      -0.654654  -0.741433       1.380131
# 6        -0.860829      0.620174      -0.654654   1.505333      -0.690066
# 7        -0.860829     -0.620174      -0.654654  -0.741433      -1.035098
# 8        -1.043984     -1.240347      -0.654654  -0.516756      -0.690066
# 9        -1.410294      0.000000      -0.654654  -0.741433       1.035098

# %% [markdown]
# Pairwise plot to understand realtionship between variables.

# %%
# importing seaborn for statistical plots
sns.pairplot(custDataScaled, height=2,aspect=2 , diag_kind='kde')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ##### **Dendogram using average linkage**

# %%
Z = linkage(custDataScaled, metric='euclidean', method='average')

# %%
Z.shape
# Out:
# (9, 4)

# %%
Z
# Out:
# array([[ 7.        ,  8.        ,  0.76660834,  2.        ],
#        [ 5.        ,  9.        ,  1.30817103,  2.        ],
#        [ 2.        ,  3.        ,  1.33188797,  2.        ],
#        [ 4.        ,  6.        ,  1.48252699,  2.        ],
#        [10.        , 11.        ,  2.29187962,  4.        ],
#        [ 1.        , 13.        ,  3.01368978,  3.        ],
#        [ 0.        , 12.        ,  3.12171991,  3.        ],
#        [14.        , 15.        ,  3.23053961,  7.        ],
#        [16.        , 17.        ,  3.78685213, 10.        ]])

# %%
fig, ax = plt.subplots(figsize=(20, 12))
dendrogram(Z, labels=custDataScaled.index, ax=ax, color_threshold=2)
plt.xticks(rotation=90)
ax.set_ylabel('distance')
ax.set_xlabel('sample index')
ax.set_title("Dendogram using Average linkage")
# Out:
# Text(0.5, 1.0, 'Dendogram using Average linkage')

# %% [markdown]
# ##### **Dendogram using complete linkage**

# %%
Z = linkage(custDataScaled, metric='euclidean', method='complete')

# %%
fig, ax = plt.subplots(figsize=(20, 12))
dendrogram(Z, labels=custDataScaled.index, ax=ax, color_threshold=2)
plt.xticks(rotation=90)
ax.set_ylabel('distance')
ax.set_xlabel('sample index')
ax.set_title("Dendogram using Complete linkage")
# Out:
# Text(0.5, 1.0, 'Dendogram using Complete linkage')

# %% [markdown]
# ##### **Dendogram using ward method**

# %%
Z = linkage(custDataScaled, metric='euclidean', method='ward')

# %%
fig, ax = plt.subplots(figsize=(20, 12))
dendrogram(Z, labels=custDataScaled.index, ax=ax, color_threshold=2)
plt.xticks(rotation=90)
ax.set_ylabel('distance')
ax.set_xlabel('sample index')
ax.set_title("Dendogram using Ward linkage")
# Out:
# Text(0.5, 1.0, 'Dendogram using Ward linkage')

# %% [markdown]
# #### **Calculating the number of clusters**

# %%
fig, ax = plt.subplots(figsize=(20, 12))
dendrogram(Z, labels=custDataScaled.index, ax=ax, color_threshold=2)
plt.xticks(rotation=90)
plt.axhline(y=4, color='k', linestyle='--')
ax.set_ylabel('distance')
# Out:
# Text(0, 0.5, 'distance')

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean',  linkage='ward')

# %%
model.fit(custDataScaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', n_clusters=3)

# %%
custDataAttr['labels'] = model.labels_
custDataAttr.head(10)

#custDataAttr.groupby(["labels"]).count()
# Out:
#    Avg_Mthly_Spend  No_Of_Visits  Apparel_Items  FnV_Items  Staples_Items  \
# 0            10000             2              1          1              0
# 1             7000             3              0         10              9
# 2             7000             7              1          3              4
# 3             6500             5              1          1              4
# 4             6000             6              0         12              3
# 5             4000             3              0          1              8
# 6             2500             5              0         11              2
# 7             2500             3              0          1              1
# 8             2000             2              0          2              2
# 9             1000             4              0          1              7
#
#    labels
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
# 5       2
# 6       1
# 7       2
# 8       2
# 9       2

# %%
# analysis of clusters formed
h_clusters_mthly_spend = 	pd.DataFrame(custDataAttr.groupby(["labels"]).Avg_Mthly_Spend.mean())
h_clusters_num_of_visits = 	pd.DataFrame(custDataAttr.groupby(["labels"]).No_Of_Visits.mean())
h_clusters_apparel_items = 	pd.DataFrame(custDataAttr.groupby(["labels"]).Apparel_Items.mean())
h_clusters_fnv_items = 	pd.DataFrame(custDataAttr.groupby(["labels"]).FnV_Items.mean())
h_clusters_staples_items = 	pd.DataFrame(custDataAttr.groupby(["labels"]).Staples_Items.mean())

# %%
df = pd.concat([pd.Series([0,1,2]), h_clusters_mthly_spend, h_clusters_num_of_visits, h_clusters_apparel_items,h_clusters_fnv_items, h_clusters_staples_items ], axis=1)
df.columns = ["Cluster_id","Avg_Mthly_Spend","No_Of_Visits" ,"Apparel_Items", "FnV_Items", "Staples_Items"]
df.head()
# Out:
#    Cluster_id  Avg_Mthly_Spend  No_Of_Visits  Apparel_Items  FnV_Items  \
# 0           0      7833.333333      4.666667            1.0   1.666667
# 1           1      5166.666667      4.666667            0.0  11.000000
# 2           2      2375.000000      3.000000            0.0   1.250000
#
#    Staples_Items
# 0       2.666667
# 1       4.666667
# 2       4.500000

# %%
sns.barplot(x=df.Cluster_id, y=df.Avg_Mthly_Spend, hue=df.Cluster_id)
# Out:
# <Axes: xlabel='Cluster_id', ylabel='Avg_Mthly_Spend'>

# %%
sns.barplot(x=df.Cluster_id, y=df.No_Of_Visits, hue=df.Cluster_id)
# Out:
# <Axes: xlabel='Cluster_id', ylabel='No_Of_Visits'>

# %%
sns.barplot(x=df.Cluster_id, y=df.Apparel_Items, hue=df.Cluster_id)
# Out:
# <Axes: xlabel='Cluster_id', ylabel='Apparel_Items'>

# %%
sns.barplot(x=df.Cluster_id, y=df.FnV_Items, hue=df.Cluster_id)
# Out:
# <Axes: xlabel='Cluster_id', ylabel='FnV_Items'>

# %%
sns.barplot(x=df.Cluster_id, y=df.Staples_Items, hue=df.Cluster_id)
# Out:
# <Axes: xlabel='Cluster_id', ylabel='Staples_Items'>

# %% [markdown]
# Below are the insight that we can make out after analysing the above bar plots:
# 1. Customers in cluster 0 has the highest avg monthly spend, they frequently visit the store, they tend to prefer more apperal items and very lesser FnV and staple items.We can target these customer more apperal related ads.
# 2. Customers in cluster 1 has the second highest avg monthly spend, with highest number of visits to the store, they tend to buy more of FnV and staple items and almost no apperal items.We can target these customer more FnV and staple items related ads.
# 3. Customers in cluster 2 has the least avg monthly spend, with lesser number of visits to the store, they tend to buy more staple items and less of FnV items and almost no apperal items.We can target these customer more FnV and staple items related ads where top priorty goes to staple items.

# %% [markdown]
# ### Advantages and disatvantages of Aggloromative clustering

# %% [markdown]
# **Advantages of Hierarchical Clustering:**
#
# - We do not need to specify the number of clusters required for the algorithm.
# - Hierarchical clustering is easy to implement.
# - The dendrogram produced is very useful in understanding the data.
#
# **Disadvantages of Aggloromative clustering:**
#
# - Not suitable for large datasets due to high time and space complexity.
#   - The time required to run the algorithm increases exponentially as the number of data points increases, making it difficult to use for large datasets.
#   - As data increases storage requirement would also increase because of similarity/proximity matrix that we are building.

# %% [markdown]
# ### Kmeans vs Aggloromative clustering:

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/067/283/original/Screenshot_2024-03-05_at_4.32.26_PM.png?1709636573)
